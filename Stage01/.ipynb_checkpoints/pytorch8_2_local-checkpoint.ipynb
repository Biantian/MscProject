# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# import numpy as np
import random
import matplotlib.pyplot as plt
import torchvision
import torch
import torch.nn as nn 
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torch.autograd import Variable
import os
# np.random.seed(3)
random.seed(3)
torch.manual_seed(3)

# %% [markdown]
# # Data Augmentation
#
# image size: 227\*227

# %%
transform = {
    "train": transforms.Compose([
        transforms.RandomRotation(10),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(brightness=0.35),
        transforms.Resize(227),
        transforms.CenterCrop(227),
        transforms.ToTensor(),
        transforms.Normalize(mean =[0.485,0.456,0.406], std = [0.229,0.224,0.225])
    ]),
    "Test": transforms.Compose({
        transforms.Resize(227),
        transforms.CenterCrop(227),
        transforms.ToTensor(),
        transforms.Normalize(mean =[0.485,0.456,0.406], std = [0.229,0.224,0.225])
    })
}

# %% [markdown]
# ## Load Image Folder

# %%
root='E:/Resource/Dataset/Practice/flowers'

full_dataset = datasets.ImageFolder(os.path.join(root,'flowers'),transform=transform["train"])
class_names = full_dataset.classes
print('full dataset:',full_dataset)
print('Classes:',class_names)
# Out:
# full dataset: Dataset ImageFolder
#     Number of datapoints: 4323
#     Root location: E:/Resource/Dataset/Practice/flowers\flowers
#     StandardTransform
# Transform: Compose(
#                RandomRotation(degrees=(-10, 10), resample=False, expand=False)
#                RandomHorizontalFlip(p=0.5)
#                ColorJitter(brightness=[0.65, 1.35], contrast=None, saturation=None, hue=None)
#                Resize(size=227, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(227, 227))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Classes: ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %% [markdown]
# # Split train val and test set

# %%
train_size = int(0.7 * len(full_dataset))
test_size = int((len(full_dataset) - train_size)/2)
val_size = len(full_dataset) - train_size - test_size

print('Train set:',train_size)
print('Validation set:',val_size)
print('Test set:',test_size)
train_data, val_data, test_data = torch.utils.data.random_split(
    full_dataset, 
    [train_size, val_size, test_size])
# Out:
# Train set: 3026
# Validation set: 649
# Test set: 648

# %%
train_btch_size = 16
val_btch_size = 16
test_btch_size = 32

train_loader = DataLoader(train_data,batch_size=train_btch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_data,batch_size=val_btch_size, shuffle=False, num_workers=4)
test_loader =  DataLoader(test_data,batch_size =test_btch_size, shuffle=False)

# %% [markdown]
# # CNN

# %%
class ConvNet6(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3,32,kernel_size=3,stride=2),# (227-3)/2+1 = 113
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Dropout(p=0.25)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(32,64,kernel_size=3,stride=2), # (113-3)/2+1 = 56
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2), # 56/2 = 28
            nn.BatchNorm2d(64),
            nn.Dropout(p=0.2)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(64,128,kernel_size=3,stride=1), # (28-3)/1+1=26
            nn.ReLU(),
            nn.BatchNorm2d(128),
        )
        self.layer4 = nn.Sequential(
            nn.Conv2d(128,256,kernel_size=3,stride=1),# (26-3)/1+1=24
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),# 24/2=12
            nn.BatchNorm2d(256),
            nn.Flatten()
        )

        self.classifier = nn.Sequential(
            nn.Linear(256*12*12,1024),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(1024,512),
            nn.ReLU(),
            nn.Linear(512,5)     
        )
        
    def forward(self,X):
        X = self.layer1(X)
        X = self.layer2(X)
        X = self.layer3(X)
        X = self.layer4(X)
        X = self.classifier(X)
        return X

# %%
class ConvNet7(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3,32,kernel_size=3,stride=2),# (227-3)/2+1 = 113
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Dropout(p=0.25)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(32,64,kernel_size=3,stride=2), # (113-3)/2+1 = 56
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2), # 56/2 = 28
            nn.BatchNorm2d(64),
            nn.Dropout(p=0.2)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(64,128,kernel_size=3,stride=1), # (28-3)/1+1=26
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.Dropout(p=0.2)
        )
        self.layer4 = nn.Sequential(
            nn.Conv2d(128,256,kernel_size=3,stride=1),# (26-3)/1+1=24
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),# 24/2=12
            nn.BatchNorm2d(256),
            nn.Flatten()
        )

        self.classifier = nn.Sequential(
            nn.Linear(256*12*12,1024),
            nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.2),
            nn.Linear(1024,512),
            nn.ReLU(),
            nn.Linear(512,5)     
        )
        
    def forward(self,X):
        X = self.layer1(X)
        X = self.layer2(X)
        X = self.layer3(X)
        X = self.layer4(X)
        X = self.classifier(X)
        return X

# %% [markdown]
# # Check GPU

# %% [markdown]
# > scheduler stands for learning rate decay.

# %%
# networks: ConvNet1,2,3,4,5,6,7
net = ConvNet6()
criterion = nn.CrossEntropyLoss()
use_gpu = torch.cuda.is_available()
# use_gpu = False ##############################
if use_gpu:
    net.cuda()
    criterion = criterion.cuda()
    # get gpu information
    device_id = torch.cuda.current_device()
    device_num = torch.cuda.device_count()
    device_name = torch.cuda.get_device_name(device_id)
    print("GPU available")
    print("Device name:",device_name)
    print("Device number:",device_num)
else:
    print("GPU not avaliable") 

# epoch
epochs = 40

# optimizer
optimizer = torch.optim.Adam(net.parameters(),lr=0.001)

# scheduler
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma = 0.95)
print(net)
# Out:
# GPU available
# Device name: GeForce GTX 1060 with Max-Q Design
# Device number: 1
# ConvNet6(
#   (layer1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Dropout(p=0.2, inplace=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Flatten()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=36864, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %% [markdown]
# # Train and Test
#
# `trn_corr+=(predicted == y_train).sum()`:<br>
# `predicted` and `y_train` are matrixs of the same size (normally (1,20)).<br>
# `np.sum()` will calculate the total number of result that satisfy the condition.
# [source](https://note.nkmk.me/en/python-numpy-count/).

# %%
# %%time
losses = {'train':[],'val':[]}
corrects = {'train':[],'val':[]}
for epoch in range(epochs):
    trn_corr = 0
    val_corr = 0
    trn_loss = 0
    val_loss = 0
    for batch,(X_train,y_train) in enumerate(train_loader):
        batch+=1
        if use_gpu:
            X_train = Variable(X_train).cuda()
            y_train = Variable(y_train).cuda()
    
        y_pred = net(X_train)
        loss = criterion(y_pred,y_train)
        predicted =torch.max(y_pred.data,1)[1]
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        trn_loss += loss.item()*X_train.size(0)
        trn_corr += (predicted == y_train).sum()

        if batch%80 ==0:
            print(f'epoch:{epoch} batch:{batch} loss:{loss.item()} accuracy:{trn_corr.item()*100/(batch*train_btch_size)}')
        
    scheduler.step()    
    losses['train'].append(trn_loss/train_size)
    corrects['train'].append(trn_corr.item()/train_size*100)
    

    with torch.no_grad():
        for batch,(X_val,y_val) in enumerate(val_loader):
            if use_gpu:
                X_val = Variable(X_val).cuda()
                y_val = Variable(y_val).cuda()

            output_val= net(X_val)
            predicted = torch.max(output_val.data,1)[1]
            loss = criterion(output_val,y_val)
            val_corr += (predicted==y_val).sum()
            val_loss += loss.item()*X_val.size(0)

        losses['val'].append(val_loss/val_size)
        corrects['val'].append(val_corr.item()/val_size*100)
# Out:
# epoch:0 batch:80 loss:1.1787505149841309 accuracy:37.34375
# epoch:0 batch:160 loss:1.3227479457855225 accuracy:40.46875
# epoch:1 batch:80 loss:1.9712787866592407 accuracy:47.1875
# epoch:1 batch:160 loss:1.403831124305725 accuracy:46.6796875
# epoch:2 batch:80 loss:1.1755249500274658 accuracy:51.875
# epoch:2 batch:160 loss:1.3133697509765625 accuracy:52.265625
# epoch:3 batch:80 loss:0.9309637546539307 accuracy:57.5
# epoch:3 batch:160 loss:1.5000736713409424 accuracy:57.7734375
# epoch:4 batch:80 loss:0.8915137052536011 accuracy:55.15625
# epoch:4 batch:160 loss:1.1191725730895996 accuracy:55.625
# epoch:5 batch:80 loss:1.3292688131332397 accuracy:62.34375
# epoch:5 batch:160 loss:1.0398427248001099 accuracy:62.1875
# epoch:6 batch:80 loss:0.673532247543335 accuracy:63.828125
# epoch:6 batch:160 loss:0.5128157734870911 accuracy:63.3984375
# epoch:7 batch:80 loss:0.9424104690551758 accuracy:65.9375
# epoch:7 batch:160 loss:1.357236385345459 accuracy:65.1171875
# epoch:8 batch:80 loss:0.982847273349762 accuracy:69.6875
# epoch:8 batch:160 loss:0.9367690086364746 accuracy:67.734375
# epoch:9 batch:80 loss:0.5080992579460144 accuracy:70.9375
# epoch:9 batch:160 loss:1.2453064918518066 accuracy:70.8984375
# epoch:10 batch:80 loss:0.9423953890800476 accuracy:72.65625
# epoch:10 batch:160 loss:0.45286494493484497 accuracy:71.796875
# epoch:11 batch:80 loss:0.7044504284858704 accuracy:73.671875
# epoch:11 batch:160 loss:0.4273553490638733 accuracy:73.4765625
# epoch:12 batch:80 loss:0.697079062461853 accuracy:77.34375
# epoch:12 batch:160 loss:0.7701029777526855 accuracy:76.7578125
# epoch:13 batch:80 loss:0.5401319265365601 accuracy:78.515625
# epoch:13 batch:160 loss:0.6991782188415527 accuracy:77.421875
# epoch:14 batch:80 loss:0.5782572627067566 accuracy:78.984375
# epoch:14 batch:160 loss:0.6799947619438171 accuracy:78.984375
# epoch:15 batch:80 loss:0.5781733989715576 accuracy:79.53125
# epoch:15 batch:160 loss:0.7658057808876038 accuracy:79.8046875
# epoch:16 batch:80 loss:0.32822054624557495 accuracy:83.828125
# epoch:16 batch:160 loss:0.5985973477363586 accuracy:83.0859375
# epoch:17 batch:80 loss:0.5057099461555481 accuracy:85.859375
# epoch:17 batch:160 loss:0.28307995200157166 accuracy:84.7265625
# epoch:18 batch:80 loss:0.1513906866312027 accuracy:86.09375
# epoch:18 batch:160 loss:0.06775137037038803 accuracy:86.5625
# epoch:19 batch:80 loss:0.6281328797340393 accuracy:88.90625
# epoch:19 batch:160 loss:0.19821569323539734 accuracy:88.2421875
# epoch:20 batch:80 loss:0.47895538806915283 accuracy:90.46875
# epoch:20 batch:160 loss:0.3721417784690857 accuracy:89.6484375
# epoch:21 batch:80 loss:0.04766979068517685 accuracy:91.640625
# epoch:21 batch:160 loss:0.26573920249938965 accuracy:90.859375
# epoch:22 batch:80 loss:0.36802801489830017 accuracy:92.734375
# epoch:22 batch:160 loss:0.4158822298049927 accuracy:92.34375
# epoch:23 batch:80 loss:0.02153569646179676 accuracy:92.109375
# epoch:23 batch:160 loss:0.27601829171180725 accuracy:92.4609375
# epoch:24 batch:80 loss:0.3157709836959839 accuracy:93.75
# epoch:24 batch:160 loss:0.3829217553138733 accuracy:93.8671875
# epoch:25 batch:80 loss:0.09098642319440842 accuracy:95.0
# epoch:25 batch:160 loss:0.010638793930411339 accuracy:95.078125
# epoch:26 batch:80 loss:0.08211269974708557 accuracy:95.625
# epoch:26 batch:160 loss:0.027176987379789352 accuracy:95.1171875
# epoch:27 batch:80 loss:0.20382879674434662 accuracy:96.171875
# epoch:27 batch:160 loss:0.10603977739810944 accuracy:95.546875
# epoch:28 batch:80 loss:0.09088707715272903 accuracy:95.46875
# epoch:28 batch:160 loss:0.18991848826408386 accuracy:96.015625
# epoch:29 batch:80 loss:0.0832899883389473 accuracy:97.1875
# epoch:29 batch:160 loss:0.08368365466594696 accuracy:97.0703125
# epoch:30 batch:80 loss:0.017824923619627953 accuracy:96.953125
# epoch:30 batch:160 loss:0.016312776133418083 accuracy:97.0703125
# epoch:31 batch:80 loss:0.021770788356661797 accuracy:97.96875
# epoch:31 batch:160 loss:0.2204216718673706 accuracy:97.578125
# epoch:32 batch:80 loss:0.35997357964515686 accuracy:97.734375
# epoch:32 batch:160 loss:0.025641795247793198 accuracy:97.578125
# epoch:33 batch:80 loss:0.11592058837413788 accuracy:97.734375
# epoch:33 batch:160 loss:0.025708496570587158 accuracy:97.578125
# epoch:34 batch:80 loss:0.16590556502342224 accuracy:97.1875
# epoch:34 batch:160 loss:0.022441700100898743 accuracy:97.2265625
# epoch:35 batch:80 loss:0.0014002809766680002 accuracy:98.046875
# epoch:35 batch:160 loss:0.02628985233604908 accuracy:98.203125
# epoch:36 batch:80 loss:0.02793905884027481 accuracy:98.515625
# epoch:36 batch:160 loss:0.005003540311008692 accuracy:98.3984375
# epoch:37 batch:80 loss:0.05225485563278198 accuracy:98.75
# epoch:37 batch:160 loss:0.0029465605039149523 accuracy:98.8671875
# epoch:38 batch:80 loss:0.03744460269808769 accuracy:99.453125
# epoch:38 batch:160 loss:0.00730891153216362 accuracy:98.90625
# epoch:39 batch:80 loss:0.003749389201402664 accuracy:98.359375
# epoch:39 batch:160 loss:0.015510663390159607 accuracy:98.59375
# Wall time: 16min 25s

# %% [markdown]
# ## Save Model
# [PyTorch Document](https://pytorch.org/tutorials/beginner/saving_loading_models.html).

# %%
import time
saving_time = time.strftime("%Y%m%d%H%M%S")
path = os.path.join(root,"models/{}_{}_{}.pth")
net_name = type(net).__name__
path = path.format(net_name,epochs,saving_time)
torch.save(net.state_dict(),path)

# %% [markdown]
# # Visualize Result

# %%
#  Plot train loss and val loss 
plt.figure(figsize=(8,6))
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(losses['train'],label = 'train')
plt.plot(losses['val'],label  = 'validation')
plt.legend()

#  Plot train and val accuracy
plt.figure(figsize=(8,6))
plt.xlabel("Epoch")
plt.ylabel("Accuracy(%)")
plt.plot(corrects['train'],label = 'train')
plt.plot(corrects['val'], label = 'validation')
plt.legend()

# %% [markdown]
# ## Accuracy on Testset
# ConvNet1 40 epochs 0.7191 24min45s <br/>
# ConvNet2 40 epochs 0.6991 16min15s <br/>
# ConvNet3 40 epochs 0.7238 18min56s <br/>
# ConvNet4 40 epochs 0.7052 18min37s <br/>
# ConvNet5 40 epochs 0.7099 16min55s <br/>
# ConvNet6 40 epochs 0.7423 16min27s <br/>
# ConvNet7 40 epochs 0.7454 16min25s <br/>

# %%
correct = 0
total = 0
y_true = []
y_pred = []

with torch.no_grad():
    for batch,data in enumerate(test_loader):
        X,y = data
        if use_gpu:
            X = Variable(X).cuda()
            y = Variable(y).cuda()
        output = net(X)
        for i, pred in enumerate(output):
            y_true.append(y[i].item())
            y_pred.append(torch.argmax(pred).item())
            if torch.argmax(pred) == y[i]:
                correct += 1
            total += 1
print("Accuracy: ", round(correct/total, 4))
# Out:
# Accuracy:  0.7454

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix,classification_report
import numpy as np

def plot_confusion_matrix(cm, class_names, title='Confusion Matrix'):
    cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis] # normalization
    plt.imshow(cm, interpolation='nearest')
    plt.title(title)
    plt.colorbar()
    num_local = np.array(range(len(class_names)))
    plt.xticks(num_local, class_names, rotation=90)
    plt.yticks(num_local, class_names)
    plt.ylabel('True label')    
    plt.xlabel('Predicted label')

# %%
print(classification_report(y_true,y_pred,target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#        daisy       0.83      0.70      0.76       120
#    dandelion       0.71      0.82      0.76       139
#         rose       0.72      0.65      0.68       122
#    sunflower       0.80      0.80      0.80       118
#        tulip       0.70      0.75      0.73       149
#
#     accuracy                           0.75       648
#    macro avg       0.75      0.74      0.75       648
# weighted avg       0.75      0.75      0.74       648

# %%
cm = confusion_matrix(y_true,y_pred,) # labels' order follow the order of digits
print(cm)
# Out:
# [[ 84  18   5   4   9]
#  [  7 114   5   9   4]
#  [  4   6  79   5  28]
#  [  4  12   2  94   6]
#  [  2  11  18   6 112]]

# %%
plot_confusion_matrix(cm,class_names,"ConvNet Confusion Matrix")
# plt.savefig('/{net_name}_cm.png'.format(),format='png'))
plt.show()

# %% [markdown]
# ## CORRECTLY CLASSIFIED FLOWER IMAGES

# %%
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
bi_map = np.array(y_true)==np.array(y_pred)
count = 0
for batch,(X,y) in enumerate(test_loader):
    for i,img in enumerate(X):
        idx = batch*test_btch_size+i
        if bi_map[idx]:
            i=int(count/2)
            j=count%2
            im_inv = transforms.Normalize( 
                mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
                std=[1/0.229, 1/0.224, 1/0.225])
            img = im_inv(img)
            ax[i,j].imshow(np.transpose(img.numpy(),(1,2,0)))
            ax[i,j].set_title("Predicted Flower:"+
                              class_names[y_pred[idx]]+"\n"+
                             "Actual Flower:"+
                             class_names[y_true[idx]])
            plt.tight_layout()
            count+=1
        if count==8:
            break
    if count==8:
        break

# %% [markdown]
# ## INCORRECTLY CLASSIFIED FLOWER IMAGES

# %%
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
bi_map = np.array(y_true)==np.array(y_pred)
count = 0
for batch,(X,y) in enumerate(test_loader):
    for i,img in enumerate(X):
        idx = batch*test_btch_size+i
        if bi_map[idx]==False:
            i=int(count/2)
            j=count%2
            im_inv = transforms.Normalize( 
                mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
                std=[1/0.229, 1/0.224, 1/0.225])
            img = im_inv(img)
            ax[i,j].imshow(np.transpose(img.numpy(),(1,2,0)))
            ax[i,j].set_title("Predicted Flower:"+
                              class_names[y_pred[idx]]+"\n"+
                             "Actual Flower:"+
                             class_names[y_true[idx]])
            plt.tight_layout()
            count+=1
        if count==8:
            break
    if count==8:
        break
